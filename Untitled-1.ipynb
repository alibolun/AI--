# %%
[project]
name = "food-recipe-recommender"
version = "0.1.0"
description = "AI-powered recipe recommender based on uploaded food images"
readme = "README.md"
requires-python = ">=3.10"
dependencies = [
    "langchain>=0.3.0",
    "langchain-community>=0.3.0",
    "langchain-openai>=0.2.0",
    "langchain-core>=0.3.0",
    "streamlit>=1.40.0",
    "pillow>=11.0.0",
    "python-dotenv>=1.0.0",
    "tavily-python>=0.5.0",
    "langchain-tavily>=0.1.0",
    "fastapi>=0.109.0",
    "uvicorn>=0.27.0",
    "python-multipart>=0.0.6",
    "alibabacloud-oss-v2>=1.2.4",
    "langgraph-checkpoint-sqlite>=3.0.3",
]

[tool.uv]
dev-dependencies = [
    "pytest>=8.0.0",
    "black>=24.0.0",
]
# Out:
#   Cell In[15], line 6
#     requires-python = ">=3.10"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# 加载环境变量
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model
import os

model = init_chat_model(
    model="qwen3.5-plus",  # 模型名称，这里选择qwen3.5-plus，这是一个多模态模型
    model_provider="openai",
    base_url=os.getenv("DASHSCOPE_BASE_URL"),
    api_key=os.getenv("DASHSCOPE_API_KEY")
)

# %%
from langgraph.checkpoint.sqlite import SqliteSaver
import sqlite3

# 连接sqlite
connection = sqlite3.connect("resources/personal_chief.db", check_same_thread=False)
# 初始化checkpointer
checkpointer = SqliteSaver(connection)
# 自动建表
checkpointer.setup()

# %%
from langchain_tavily import TavilySearch

# web搜索工具，使用tavily作为web搜索工具
web_search = TavilySearch(
    max_results=5,
    topic="general",
)

# %%
from langchain.agents import create_agent

system_prompt = """
你是一名私人厨师。收到用户提供的食材照片或清单后，请按以下流程操作：
1.识别和评估食材：若用户提供照片，首先辨识所有可见食材。基于食材的外观状态，评估其新鲜度与可用量，整理出一份“当前可用食材清单”。
2.智能食谱检索：优先调用 web_search 工具，以“可用食材清单”为核心关键词，查找可行菜谱。
3.多维度评估与排序：从营养价值和制作难度两个维度对检索到的候选食谱进行量化打分，并根据得分排序，制作简单且营养丰富的排名靠前。
4.结构化方案输出：把排序后的食谱整理为一份结构清晰的建议报告，要包含食谱信息、得分、推荐理由、食谱的参考图片，帮助用户快速做出决策。

请严格按照流程，优先调用 web_search 工具搜索食谱，搜索不到的情况下才能自己发挥。
"""

agent = create_agent(
    model=model,
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=checkpointer
)

# %%
from langchain.messages import HumanMessage

# 准备多模态消息，图片是网络上的冰箱食物图片
multimodal_message = HumanMessage(
    content=[
        {"type": "image",
         "url": "https://img.freepik.com/free-photo/arrangement-different-foods-organized-fridge_23-2149099882.jpg"},
        {"type": "text", "text": "帮我看看这些食材能做些什么？"}
    ])

config = {"configurable": {"thread_id": "6"}}

response = agent.invoke({"messages": [multimodal_message]}, config)

# %%
# 友好打印
for message in response['messages']:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# [{'type': 'image', 'url': 'https://img.freepik.com/free-photo/arrangement-different-foods-organized-fridge_23-2149099882.jpg'}, {'type': 'text', 'text': '帮我看看这些食材能做些什么？'}]
# ================================ Human Message =================================
#
# [{'type': 'image', 'url': 'https://img.freepik.com/free-photo/arrangement-different-foods-organized-fridge_23-2149099882.jpg'}, {'type': 'text', 'text': '帮我看看这些食材能做些什么？'}]
# ================================ Human Message =================================
#
# [{'type': 'image', 'url': 'https://img.freepik.com/free-photo/arrangement-different-foods-organized-fridge_23-2149099882.jpg'}, {'type': 'text', 'text': '帮我看看这些食材能做些什么？'}]
# ================================ Human Message =================================
#
# [{'type': 'image', 'url': 'https://img.freepik.com/free-photo/arrangement-different-foods-organized-fridge_23-2149099882.jpg'}, {'type': 'text', 'text': '帮我看看这些食材能做些什么？'}]
# ================================ Human Message =================================
#
# [{'type': 'image', 'url': 'https://img.freepik.com/free-photo/arrangement-different-foods-organized-fridge_23-2149099882.jpg'}, {'type': 'text', 'text': '帮我看看这些食材能做些什么？'}]
# ================================ Human Message =================================
#
# [{'type': 'image', 'url': 'https://img.freepik.com/free-photo/arrangement-different-foods-organized-fridge_23-2149099882.jpg'}, {'type': 'text', 'text': '帮我看看这些食材能做些什么？'}]
# ================================ Human Message =================================
#
# [{'type': 'image', 'url': 'https://img.freepik.com/free-photo/arrangement-different-foods-organized-fridge_23-2149099882.jpg'}, {'type': 'text', 'text': '帮我看看这些食材能做些什么？'}]
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search (call_b602b79b7d7c4e5396d874aa)
#  Call ID: call_b602b79b7d7c4e5396d874aa
#   Args:
#     query: 三文鱼 鸡胸肉 西兰花 彩椒 蘑菇 土豆 食谱 减脂餐
#     search_depth: advanced
# ================================= Tool Message =================================
# Name: tavily_search
#
# {"query": "三文鱼 鸡胸肉 西兰花 彩椒 蘑菇 土豆 食谱 减脂餐", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://k.sina.cn/article_6920457792_19c7dce4000100uh98.html", "title": "七日减脂餐，晚餐篇|土豆|黑胡椒|主食|鸡胸肉|三文鱼_新浪新闻", "content": "我们按照1/4的主食，1/4的三文鱼以及1/2的土豆，配上几颗西兰花，就是我们一天的减脂晚餐。\n\n第四天到第七天\n\n第四天以后我们就可以选择一些低热量的蔬菜。我们可以选择这样搭配，红薯、紫薯和洋葱可以作为一种选择，红辣椒、南瓜和西葫芦则是另外一种选择。将这些蔬菜切块儿，按照搭配分好，分别放在烤盘的两边，再在两边放上一些樱桃番茄，樱桃番茄的热量很低，不会带来太多的卡路里。撒上小半勺的橄榄油，时加入意大利香草粉、海盐、黑胡椒粉，烤箱温度设置为190℃，烤至三十至四十分钟，蔬菜就熟了。\n\n我们选择在这份晚餐中加入鸡胸肉。选择300克的鸡胸肉，将鸡胸肉切成条状，放入锅中，直接加油、海盐、胡椒粉以及香草粉。挤上新鲜的柠檬汁，注意不要把柠檬籽挤进去，还要放入大约两勺的纯番茄酱。在这里我们也给素食主义者提供另外一种替代品:豆腐，加入同样的调味料即可。鸡胸肉或者豆腐用中火或者大火煎炒10到15分钟，炒的时候要注意防止飞溅。\n\n在主食的选择上我们可以和前三天的主食一样，选择藜麦或者糙米。我们用芦笋来代替每周必吃的西兰花。\n\n七日减脂餐，晚餐篇\n\n七日减脂餐，晚餐篇\n\n同样按照1/4的主食，1/4的鸡胸肉和1/2的烤蔬菜，再加入几颗芦笋，后四天的减脂晚餐就是这样啦。\n\n减肥一时爽，一直减肥一直爽。减肥其实是一个长期的过程，在这个过程中，我们要做的就是坚持，并且自律。只有我们足够坚强和自律，对自己的身材管理到位，控制好我们对热量的摄入，我们也能拥有完美的身材。 [...] ## 新浪网\n\n# 七日减脂餐，晚餐篇\n\n## 巨裕谈体育\n\n### 确定不再关注此人吗\n\n在中国式的饮食关系，晚餐时间是一个吃的最少的时间段，但是在我们的减脂饮食关系中，似乎并没有严格遵循这样的饮食关系。反而在我们的饮食中，加入了一些肉类，而卡路里却依旧控制得很低。\n\n七日减脂餐，晚餐篇\n\n七日减脂餐，晚餐篇\n\n第一天至第三天:土豆三文鱼\n\n首先，我们准备新鲜的土豆，将其去皮、洗净、切块，在准备土豆的同时，我们可以将烤箱预热到180度，在烤盘上铺上一层锡纸，把土豆放在烤盘的一边，撒上少量食用油，马上一些香草粉，黑胡椒和香油，将其放入烤箱，设置温度为180℃，烤制30到50分钟。\n\n从营养学的角度来讲，这些土豆只能让我们增加70千卡，所以我们可以在我们的晚餐中加入一些其他的食材。\n\n主食我们选择藜麦或者糙米，煮藜麦时热水的量大约是藜麦的三倍，注意15分钟之后从火上取下来，可以根据我们的需求量来选择煮主食的量。\n\n七日减脂餐，晚餐篇\n\n七日减脂餐，晚餐篇\n\n土豆烤熟的时候，我们把烤盘拿出来把三文鱼放上去，放在土豆的另一边，并且用锡纸隔开土豆和鱼肉，这样就可以防止土豆和鱼的味道不会混合到一起。三文鱼的调味料，包括黑胡椒、海盐、鲜柠檬汁。如是素食主义者，我们可以选择用一杯或者大半杯煮熟的鹰嘴豆，放入烤箱中，然后添加一勺食用油、海盐、黑胡椒和辣椒。三文鱼至少需要考15分钟，而鹰嘴豆需要烤30分钟。\n\n我们还要蒸一些西兰花，一周之内每次晚餐都要吃一点西兰花。\n\n我们按照1/4的主食，1/4的三文鱼以及1/2的土豆，配上几颗西兰花，就是我们一天的减脂晚餐。\n\n第四天到第七天", "score": 0.852752, "raw_content": null}, {"url": "https://cookpad.com/tw/%E9%A3%9F%E8%AD%9C/13394466", "title": "三文魚&雞胸肉 食譜與作法 by Suky🤭 - Cookpad", "content": "已收藏    \n\n收藏食譜以便日後查看\n\n## 料理步驟\n\n25mins\n\n1. 1\n\n   將三文魚和雞胸肉清理乾淨 加入適量鹽和黑胡椒醃製30分鐘\n2. 2\n\n   西蘭花切一口的大小 番茄切片 薯仔切片（用水浸下）\n3. 3\n\n   焗爐盤刷上一點油 放上番茄土豆和西蘭花 將三文魚和雞胸肉放在蔬菜上面 再將檸檬片放在肉上 放適量的鹽和胡椒粉\n4. 4\n\n   烤25分鐘（180 °C）就可以啦✌️\n\n已收藏    \n\n收藏食譜以便日後查看\n\n編輯食譜\n\n 查看食譜數據 \n\n增加到資料夾\n\n上傳試做成品照\n\n分享\n\n 已複製\n 電子郵件信箱\n Facebook\n Pinterest\n Twitter\n\n 列印 \n\n 列印\n 上傳試做成品照\n 檢舉食譜\n\n 查看食譜數據\n\n 刪除\n\n## 試做成品照\n\n已收藏    \n\n收藏食譜以便日後查看\n\n 上傳試做成品照\n 增加到資料夾\n 列印\n 分享\n\n  + 已複製\n  + 電子郵件信箱\n  + Facebook\n  + Pinterest\n  + Twitter\n 檢舉食譜\n 查看食譜數據\n 編輯食譜\n 刪除\n\n已複製\n\nSuky🤭    @Suky\\_0001\n\n發布於\n\n00年喜歡烹飪🍳的女孩😉\n\n 繼續閱讀\n\n## 留言\n\n訪客\n\n## 相似食譜\n\n更多推薦食譜\n\n1. 家常蔥滷豆干\n2. 蕃茄蛋豆皮\n3. 肉絲炒時蔬\n4. 麻辣豆腐\n5. 醬炒豆皮金針菇\n\n1. 無麩質土司\n2. 伯爵茶瑪德蓮蛋糕 Earl Grey Madeleines\n3. 【COOKING BUBU】🧀氣炸特濃起司曲奇\n4. 味噌卡邦尼義大利麵\n5. 滑滑嫩嫩「鮮奶燉蛋白」\n\n1. 煎飯三明治：剩飯料理\n2. 蔥香椒鹽蝦\n3. 清爽雞肉春筍\n4. 【厚生廚房】黑糖檸檬愛玉\n\nCookpad 在 Cookpad App 開啟 [...] 三文魚&雞胸肉\n\n收藏食譜以便日後查看\n\n 上傳試做成品照\n 增加到資料夾\n 列印\n 分享\n\n  + 已複製\n  + 電子郵件信箱\n  + Facebook\n  + Pinterest\n  + Twitter\n 檢舉食譜\n 查看食譜數據\n 編輯食譜\n 刪除\n\n 登入\n 新增食譜\n\nCookpad Cookpad\n\n下載應用程式\n\n# 三文魚&雞胸肉\n\nSuky🤭   @Suky\\_0001\n\n健康的飲食   \n（配菜方面可以選擇自己鍾意既蔬菜）\n\n健康的飲食   \n（配菜方面可以選擇自己鍾意既蔬菜）\n\n 繼續閱讀\n\n# 三文魚&雞胸肉\n\nSuky🤭   @Suky\\_0001\n\n健康的飲食   \n（配菜方面可以選擇自己鍾意既蔬菜）\n\n健康的飲食   \n（配菜方面可以選擇自己鍾意既蔬菜）\n\n 繼續閱讀\n\n已收藏    \n\n收藏食譜以便日後查看\n\n編輯食譜\n\n 查看食譜數據 \n\n增加到資料夾\n\n上傳試做成品照\n\n分享\n\n 已複製\n 電子郵件信箱\n Facebook\n Pinterest\n Twitter\n\n 列印 \n\n 列印\n 上傳試做成品照\n 檢舉食譜\n\n 查看食譜數據\n\n 刪除\n\n 已複製\n 電子郵件信箱\n Facebook\n Pinterest\n Twitter\n\n收藏食譜以便日後查看\n\n 上傳試做成品照\n 增加到資料夾\n 列印\n 檢舉食譜\n 查看食譜數據\n 編輯食譜\n 刪除\n\n## 預備食材\n\n25mins\n\n3人份\n\n1. 三文魚 兩塊\n2. 雞胸肉 一塊 （也可以用雞柳）\n3. 西蘭花 一棵\n4. 土豆 一個\n5. 番茄 一個\n6. 油\n7. 鹽\n8. 黑胡椒\n9. 檸檬\n\nCookpad 在 Cookpad App 開啟\n\n已收藏    \n\n收藏食譜以便日後查看\n\n## 料理步驟\n\n25mins\n\n1. 1 [...] Cookpad 在 Cookpad App 開啟\n\nCookpad Premium 訂閱會員", "score": 0.8127637, "raw_content": null}, {"url": "https://m.xiachufang.com/recipe/104540884/", "title": "【步骤图】减脂增肌健身餐（持续更新中）的做法_减脂增肌健身餐（持续更新中）的做法步骤_减肥_下厨房", "content": "纯奶手撕吐司的做法 步骤1\n\n香肠煎蛋、白灼金针菇、蒸玉米\n\n纯奶手撕吐司的做法 步骤1\n\n碳水：土豆泥 蛋白质+纤维：杏鲍菇炒牛肉、蒜蓉蜂蜜鸡扒\n\n### 减脂增肌健身餐（持续更新中）的小贴士\n\n不节食，也可以吃得很好。少盐少油也可以好吃，重要的是食材。\n肉类基本都是买冷冻的，蔬菜一颗大概可以吃两天，番薯土豆都是常常囤着的，早午晚餐都能吃。\n烹饪方式基本是蒸、 ...
# ================================== Ai Message ==================================
#
# 你好！我是你的私人厨师。
#
# 根据你提供的冰箱照片，你储备的食材非常棒！这是一组非常完美的**“减脂增肌”黄金组合**：
# 1.  **优质蛋白**：有三文鱼（富含Omega-3）和鸡胸肉（高蛋白低脂）。
# 2.  **多彩蔬菜**：有西兰花、口蘑、红黄彩椒、小番茄、生菜沙拉，以及底部的土豆/白萝卜。
# 3.  **新鲜度**：食材看起来色泽鲜艳，摆放整齐，新鲜度极佳。
#
# 基于这些食材，我为你搜索并定制了三份食谱，按**制作难度**和**营养均衡度**进行了评分排序。
#
# ---
#
# ### 🥗 私人厨师推荐食谱方案
#
# #### 🏆 第一名：懒人烤箱“全家福” (综合营养拼盘)
# **推荐指数：⭐⭐⭐⭐⭐**
# *   **综合评分**：95分 (制作最简单，营养最全面)
# *   **所需食材**：三文鱼、鸡胸肉、西兰花、土豆、小番茄、红黄彩椒。
# *   **推荐理由**：这是一道非常适合忙碌人士的**“无油烟”**料理。利用烤箱一次性将所有高蛋白和高纤维食材同时加热，既保留了食材的原汁原味，又最大程度锁住了营养。而且清洗只需要一个烤盘，非常省心。
# *   **参考做法**：
#     1.  **预处理**：将鸡胸肉和三文鱼切块，用少许盐、黑胡椒和柠檬汁腌制20分钟。
#     2.  **切配**：土豆切块（如果是土豆），西兰花掰小朵，彩椒切块。
#     3.  **摆盘**：烤盘铺锡纸，先铺上土豆块（烤制时间较长），再依次铺上西兰花、彩椒、小番茄、蘑菇。
#     4.  **烘烤**：将鸡肉和三文鱼放在蔬菜上面，放入预热至200℃的烤箱，烤制20-25分钟即可。
#
# #### 🥈 第二名：口蘑蒜香鸡胸肉 (鲜嫩多汁)
# **推荐指数：⭐⭐⭐⭐**
# *   **综合评分**：90分 (口感丰富，鲜味十足)
# *   **所需食材**：鸡胸肉、口蘑、红/黄彩椒、蒜。
# *   **推荐理由**：鸡胸肉如果直接水煮容易口感发柴，搭配口蘑一起炒，蘑菇的鲜味汁液会被鸡肉吸收，让肉质变得异常鲜嫩多汁。这是一道非常经典的**中式低脂热菜**。
# *   **参考做法**：
#     1.  鸡胸肉切片，加生抽、料酒、淀粉抓匀腌制。
#     2.  口蘑切片，彩椒切丝。
#     3.  锅中喷少许油，先滑炒鸡胸肉至变色盛出。
#     4.  原锅放入蒜末和口蘑，中小火炒出汁水（这一步是关键），再倒入彩椒和鸡肉翻炒均匀，加少许盐和黑胡椒出锅。
#
# #### 🥉 第三名：三文鱼牛油果温沙拉 (清爽减脂)
# **推荐指数：⭐⭐⭐⭐**
# *   **综合评分**：85分 (极速快手，健康清爽)
# *   **所需食材**：三文鱼、生菜沙拉底、小番茄、彩椒（如有牛油果或煮鸡蛋可加入）。
# *   **推荐理由**：当你不想开火做复杂的热菜时，这道沙拉是完美的选择。利用三文鱼本身的油脂，搭配清爽的蔬菜，是一道极佳的**轻食晚餐**。
# *   **参考做法**：
#     1.  三文鱼撒盐和黑胡椒，平底锅无油或少油煎熟，盛出放凉掰碎。
#     2.  生菜洗净沥干，小番茄对半切开，彩椒切圈。
#     3.  将所有蔬菜铺在盘底，放上三文鱼。
#     4.  **灵魂酱汁**：用橄榄油 + 柠檬汁 + 少许海盐 + 黑胡椒 拌匀淋在沙拉上即可。
#
# ---
#
# **💡 厨师小贴士：**
# *   **关于土豆/萝卜**：照片底部的如果是土豆，建议作为**主食**（碳水）食用，代替米饭；如果是白萝卜，可以切片煮在鸡肉汤里，非常清爽。
# *   **食材保鲜**：你的食材非常新鲜，建议三文鱼和鸡胸肉在**1-2天内**食用完毕，蔬菜类建议尽早食用以保留维生素C。
#
# 你想尝试哪一道？或者如果你需要具体的某一道菜的详细步骤，可以随时告诉我！
# ================================ Human Message =================================
#
# 我喜欢第1道菜，可以说的更详细点吗？
# ================================== Ai Message ==================================
#
# 好的！这道**「懒人烤箱综合营养拼盘」**（也叫 Sheet Pan Dinner）绝对是家庭烹饪的“性价比之王”。不仅能让你一次性吃到红肉、白肉和五彩蔬菜，而且最大的优点是——**做完几乎不需要洗锅**！
#
# 为了让你一次成功，我把细节拆解得非常具体，请查收这份**【大厨级操作指南】**：
#
# ### 🥘 菜谱名称：懒人烤箱综合营养拼盘
#
# #### 🛒 第一步：食材准备（请从冰箱取出以下食材）
#
# *   **主角（蛋白质）**：
#     *   **三文鱼**：1-2 块（如果不喜欢刺多的部位，可以检查下有没有细刺）
#     *   **鸡胸肉**：1 块
# *   **配角（蔬菜 & 碳水）**：
#     *   **土豆**：2-3 个（底部那个白色的看起来像小土豆或土豆，它是这道菜里的优质主食）
#     *   **西兰花**：适量（切小朵）
#     *   **口蘑**：5-6 个（对半切开）
#     *   **小番茄**：10-15 个（洗净即可）
#     *   **彩椒**：红/黄彩椒各半个（切块）
#
# #### 🧂 第二步：灵魂调味（这是好吃的关键！）
#
# 我们需要准备**三个小碗**，因为不同的食材需要的味道不一样：
#
# 1.  **鸡肉碗**：鸡胸肉切成约 2-3 厘米的大块。加入 **1 勺生抽**（提鲜）、**少许盐**、**黑胡椒碎**、**1 勺橄榄油**。用手抓匀，腌制 10 分钟。
# 2.  **鱼肉碗**：三文鱼表面抹干水分，撒上**少许盐**和**黑胡椒**，再挤上**几滴柠檬汁**（去腥提香，没有柠檬可省略）。
# 3.  **蔬菜碗**：把土豆块、西兰花、彩椒、口蘑放在一个大盆里，淋上 **2 勺橄榄油**，撒入 **一小撮盐** 和 **黑胡椒**，拌匀。让每块蔬菜都裹上一层油膜，烤出来才不干。
#
# #### 🔥 第三步：摆盘与进烤箱（分秒必争）
#
# 1.  **预热**：先把烤箱打开，设置 **200℃ (400℉)** 进行预热。
# 2.  **铺底**：在烤盘上铺一层**锡纸**或**烘焙纸**（这一步是为了最后不洗锅！）。
# 3.  **摆放顺序**：
#     *   **底层**：先铺**土豆块**。因为土豆最难熟，把它放在最下面接触热源，或者放在烤盘中心温度最高的地方。
#     *   **中层**：在土豆周围铺上**口蘑**、**彩椒**和**西兰花**。
#     *   **顶层**：把腌好的**鸡胸肉**和**三文鱼**摆在蔬菜的最上面。
#     *   **点缀**：最后把**小番茄**散落在空隙处。
# 4.  **进烤箱**：
#     *   放入烤箱中层。
#     *   **时间设定**：**20 - 25 分钟**。
#
# #### 👀 第四步：检查与出炉
#
# *   **20 分钟时**：打开烤箱看一眼。
#     *   用筷子扎一下**土豆**，能轻松穿透就说明熟了。
#     *   **鸡胸肉**表面应该微焦，切开后里面变白（不要烤太久，否则鸡肉会变柴）。
#     *   **三文鱼**表面变色，用叉子轻轻一拨能散开成蒜瓣状即可。
#     *   如果土豆还硬，就再烤 5-10 分钟，或者下次记得把土豆切小一点。
# *   **出炉**：取出烤盘，如果有新鲜的迷迭香或者葱花，撒一点上去增香。直接端着烤盘上桌，非常有仪式感！
#
# ---
#
# ### 💡 厨师的“避坑”小贴士：
#
# 1.  **关于鸡胸肉**：鸡胸肉最怕烤干了。秘诀是**切块不要太小**（太小容易失水），并且**表面一定要裹油**。
# 2.  **关于西兰花**：西兰花很容易烤焦。如果你切得很碎，可以晚一点放（比如烤到第 10 分钟再放进去），或者把它藏在其他蔬菜下面。
# 3.  **关于小番茄**：烤过的小番茄会爆汁，变得酸甜可口，是这道菜里的“天然酱汁”，千万别漏了它！
# 4.  **口味调整**：如果你喜欢更丰富的味道，可以在出炉后淋一点**油醋汁**或者**蜂蜜芥末酱**，风味会提升一个档次。
#
# 准备好开始了吗？如果有哪一步拿不准，随时问我！祝你做出一顿完美的健康大餐！
# ================================ Human Message =================================
#
# [{'type': 'image', 'url': 'https://img.freepik.com/free-photo/arrangement-different-foods-organized-fridge_23-2149099882.jpg'}, {'type': 'text', 'text': '帮我看看这些食材能做些什么？'}]
# ================================== Ai Message ==================================
#
# 你好！我是你的私人厨师。看到你又来咨询这些食材了，我来给你一些新的灵感！
#
# ## 📋 当前可用食材清单
#
# | 类别 | 食材 |
# |------|------|
# | **蛋白质** | 三文鱼、鸡胸肉 |
# | **蔬菜** | 西兰花、口蘑、彩椒(红/黄)、小番茄、生菜 |
# | **根茎类** | 白萝卜/土豆 |
#
# ---
#
# ## 🍽️ 今日推荐食谱（3种不同风格）
#
# ### 1️⃣ 中式快炒：彩椒口蘑炒鸡丁
# **⏱️ 耗时：15分钟 | 🔥 难度：简单**
# - 鸡胸肉切丁腌制，彩椒口蘑切块
# - 热锅少油，先炒鸡肉再下蔬菜
# - 加生抽、蚝油调味即可
# - **特点**：下饭神器，适合工作日快手餐
#
# ### 2️⃣ 日式风味：香煎三文鱼配时蔬
# **⏱️ 耗时：20分钟 | 🔥 难度：简单**
# - 三文鱼用盐和黑胡椒腌制
# - 平底锅煎至两面金黄
# - 西兰花、小番茄焯水或清炒搭配
# - **特点**：高蛋白低脂，减脂期首选
#
# ### 3️⃣ 暖胃汤品：萝卜鸡肉蔬菜汤
# **⏱️ 耗时：30分钟 | 🔥 难度：简单**
# - 白萝卜切块，鸡胸肉切块
# - 加水煮沸后放入萝卜和鸡肉
# - 最后加入西兰花、口蘑煮5分钟
# - **特点**：清淡暖胃，适合晚餐或天气凉时
#
# ---
#
# ## 💡 食材搭配建议
#
# | 目标 | 推荐组合 |
# |------|----------|
# | 🏋️ 增肌 | 三文鱼+土豆+西兰花 |
# | 🥗 减脂 | 鸡胸肉+彩椒+口蘑+生菜沙拉 |
# | 🍲 暖身 | 萝卜+鸡肉+口蘑汤 |
#
# ---
#
# ## ⚠️ 保鲜提醒
# - **三文鱼**：建议1-2天内食用
# - **鸡胸肉**：可冷藏2-3天
# - **蔬菜类**：叶菜尽早吃，根茎类可多放几天
#
# ---
#
# 你想做哪一种风格？或者告诉我你的需求（比如：想减脂/想快速搞定/想吃热的），我可以给你更详细的步骤！😊

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="我喜欢第1道菜，可以说的更详细点吗？")]},
    config
)

# 友好打印
response['messages'][-1].pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# 好的选择！这道**「彩椒口蘑炒鸡丁」**是一道超级下饭的**中式快手菜**，色彩丰富、营养均衡，而且15分钟就能搞定！让我给你一份**【大厨级详细教程】**：
#
# ---
#
# ## 🍳 彩椒口蘑炒鸡丁 - 详细版
#
# ### 🛒 第一步：食材准备（从冰箱取出）
#
# | 食材 | 用量 | 处理方式 |
# |------|------|----------|
# | 鸡胸肉 | 1块（约200g） | 切成2cm见方的小丁 |
# | 彩椒（红/黄） | 各半个 | 去籽，切成与鸡丁差不多大的块 |
# | 口蘑 | 5-6个 | 洗净，对半切开或切片 |
# | 大蒜 | 2-3瓣 | 切成蒜末 |
# | 生姜 | 2片（可选） | 切丝或末 |
#
# ---
#
# ### 🧂 第二步：腌制鸡胸肉（关键步骤！）
#
# 鸡胸肉容易发柴，腌制是让它**鲜嫩多汁**的秘诀：
#
# 1. 鸡丁放入碗中
# 2. 加入以下调料：
#    - **生抽** 1勺（约15ml）
#    - **料酒** 1勺（去腥）
#    - **淀粉** 1小勺（锁住水分，让肉更嫩）
#    - **黑胡椒** 少许
#    - **食用油** 半勺（最后加，封住水分）
# 3. 用手抓匀，腌制 **10-15分钟**
#
# > 💡 **厨师技巧**：淀粉和油是鸡胸肉嫩滑的关键，千万不要省略！
#
# ---
#
# ### 🔥 第三步：炒制步骤（全程大火快炒）
#
# ```
# 第1步：热锅凉油
# ├─ 锅烧热后倒入少许油（约1勺）
# └─ 油温6成热时（手放上方能感觉到热度）
#
# 第2步：滑炒鸡丁
# ├─ 倒入腌好的鸡丁，快速划散
# ├─ 大火炒至鸡肉变色（约2分钟）
# └─ 盛出备用（不要炒太久，否则会变老）
#
# 第3步：炒蔬菜
# ├─ 锅中留底油，放入蒜末姜丝爆香
# ├─ 先放口蘑，中火炒出水分（约2分钟）
# ├─ 再放彩椒块，大火翻炒1分钟
# └─ 彩椒断生即可，保持脆爽口感
#
# 第4步：混合调味
# ├─ 把鸡丁倒回锅中
# ├─ 加入调料：
# │   • 生抽 1勺
# │   • 蚝油 1勺（提鲜关键！）
# │   • 盐 少许（根据口味调整）
# │   • 黑胡椒 少许
# └─ 快速翻炒均匀，约30秒出锅
# ```
#
# ---
#
# ### 🍽️ 第四步：装盘上桌
#
# - 可以直接装盘，搭配米饭食用
# - 想更精致的话，可以撒点**葱花**或**白芝麻**点缀
# - 旁边可以配一份**生菜沙拉**或**焯水西兰花**，营养更均衡
#
# ---
#
# ## 💡 厨师的"加分"小贴士
#
# | 问题 | 解决方案 |
# |------|----------|
# | 鸡肉发柴 | 腌制时加淀粉和油，炒制时间不要超过3分钟 |
# | 蔬菜出水多 | 口蘑先单独炒出水分，再放彩椒 |
# | 味道不够 | 出锅前可以加几滴**香油**增香 |
# | 想要更辣 | 可以加少许**小米辣**或**辣椒粉** |
# | 想要更下饭 | 可以加一勺**豆瓣酱**，变成川味风格 |
#
# ---
#
# ## 📊 营养信息（约2人份）
#
# | 营养素 | 含量 |
# |--------|------|
# | 热量 | 约350大卡 |
# | 蛋白质 | 约35g |
# | 脂肪 | 约12g |
# | 碳水 | 约15g |
#
# 非常适合**减脂增肌**人群！
#
# ---
#
# ## ⏱️ 时间规划建议
#
# | 时间段 | 操作 |
# |--------|------|
# | 0-10分钟 | 洗菜、切菜、腌制鸡肉 |
# | 10-15分钟 | 炒制出锅 |
# | 15分钟 | 开吃！ |
#
# ---
#
# 准备好开始了吗？如果有任何步骤不清楚，随时问我！祝你做出一道色香味俱全的彩椒口蘑炒鸡丁！🍳🥘
